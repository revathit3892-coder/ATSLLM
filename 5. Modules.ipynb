# %%
import math
import numpy as np
import pandas as pd

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from Package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from Package import maths
maths.addition(2,3)
# Out:
# 5

# %%
from Package.subpackage import mul
print(mul.multiply(2,3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 from Package.subpackage import mul
#       2 print(mul.multiply(2,3))
#
# ModuleNotFoundError: No module named 'Package.subpackage'

# %%
import array
arr = array.array('i',[1,2,3,4])
arr
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
import random
print(random.randint(1,10))
print(random.choice(['Apple','Bannana','Cherry']))
# Out:
# 5
# Bannana

# %%
import os
print(os.getcwd())
print(os.mkdir("test_dir"))
# Out:
# /Users/revathithangadurai/ATSLLM/5.Modules
# None

# %%
import shutil
shutil.copyfile('/Users/revathithangadurai/ATSLLM/5.Modules/Package/source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
# Data Serialization:

import json
data = {"name":"Revt","age":37}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))
print(type(data))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Revt", "age": 37}
# <class 'str'>
# <class 'dict'>
# {'name': 'Revt', 'age': 37}
# <class 'dict'>

# %%
# csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['revt',37])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['revt', '37']

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-07-12 18:33:26.600589
# 2025-07-11 18:33:26.600589

# %%
import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1752359661.4773529
# 1752359663.482872

# %%
# Regular Expression

import re

pattern = r'\d+'
text = 'There are 123 apples 456'
match = re.findall(pattern,text)
print(match)
# Out:
# ['123', '456']

# %%
import re

pattern = r'\d+'
text = 'There are 123 apples 456'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123

# %%
re.
