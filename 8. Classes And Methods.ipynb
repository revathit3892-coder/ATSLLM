# %%
class Car:
    pass

print(type(Car))

audi = Car()
BMW = Car()

print(type(audi))
print(type(BMW))
# Out:
# <class 'type'>
# <class '__main__.Car'>
# <class '__main__.Car'>

# %%
audi.window = 4
print(audi.window)
# Out:
# 4

# %%
print(BMW.window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(BMW.window)
#
# AttributeError: 'Car' object has no attribute 'window'

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'window']

# %%
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        return f"{self.name} says woof woof"

dog1 = Dog("Buddy",5)
print(dog1.name)
print(dog1.age) 

dog2 = Dog("Era",4)
print(dog2.name)
print(dog2.age)

print(dog1.bark())
dog2.bark()
# Out:
# Buddy
# 5
# Era
# 4
# Buddy says woof woof
# 'Era says woof woof'

# %%
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self,amount):
        self.balance += amount
        print(f"{amount} is deposit and new balance is {self.balance}")
        
    def withdrawal(self,amount):
        if amount > self.balance:
            print("Insufficient Funds")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn and new balance is {self.balance}")

    def get_balance(self):
        return self.balance
    
account = BankAccount("yesh",23000)
print(account.balance)
account.withdrawal(2000)
account.deposit(300)
account.get_balance()
# Out:
# 23000
# 2000 is withdrawn and new balance is 21000
# 300 is deposit and new balance is 21300
# 21300

# %%
class Student:
    def __init__(self,name,roll_number):
        self.name = name
        self.roll_number = roll_number
        self.marks = {}

    def add_mark(self,subject,mark):
        self.marks[subject] = mark

    def average(self):
        if len(self.marks) == 0:
            return 0
        return sum(self.marks.values())/len(self.marks)

        print(f"Average is: {avg_mark}")

    def display_result(self):
        avg = self.average()
        if avg >= 40:
            print(f"{self.name},{self.roll_number} and result is pass")
        else:
            print(f"{self.name} with {self.roll_number} and result is Fail")

student_1 = Student("Alice",101)
student_1.add_mark("Maths",50)
student_1.add_mark("English",34)

student_1.display_result()
# Out:
# Alice,101 and result is pass

# %%
class Employee:

    total_employee = 0

    def __init__(self,emp_id,name,base_salary):
        self.emp_id = emp_id
        self.name = name
        self.base_salary = base_salary
        Employee.total_employee += 1

    def calculate_salary(self,bonus_percent):
        total_salary = self.base_salary + (self.base_salary * bonus_percent)/100
        return (f"{self.name}'s final salary is {total_salary}")
    
    @classmethod
    def display_total_employees(cls):
        print(f"Total employees: {cls.total_employee}")
    
emp1 = Employee("E198","Revathi",100000)
print(emp1.calculate_salary(10))

emp2 = Employee("E132","Yeshu",150000)
print(emp2.calculate_salary(10))

Employee.display_total_employees()
# Out:
# Revathi's final salary is 110000.0
# Yeshu's final salary is 165000.0
# Total employees: 2

# %%
class Book:
    def __init__(self,title,author):
        self.title = title
        self.author = author
        self.is_available = True

    def borrow(self):
        if self.is_available:
            self.is_available = False   
            return f"You have borrowed ,{self.title}"
        else:
            return f"Sorry, {self.title} is unavailable"
        
    def return_book(self):
        if not self.is_available:
            self.is_available = True   
            return f"You have returned ,{self.title}"
        else:
            return f"Sorry, {self.title} was not borrowed"

    def book_info(self):
        status = "Available" if self.is_available else "Not Available"
        print(f"Title:{self.title} \n Author:{self.author} \n Status: {status}\n ")


book1 = Book("Harry Potter", "J.K. Rowling")
book2 = Book("Atomic Habits", "James Clear")

book1.book_info()
book1.return_book()
book1.book_info()

book2.book_info()
book2.borrow()
book2.book_info()
# Out:
# Title:Harry Potter
#  Author:J.K. Rowling
#  Status: Available
#
# Title:Harry Potter
#  Author:J.K. Rowling
#  Status: Available
#
# Title:Atomic Habits
#  Author:James Clear
#  Status: Available
#
# Title:Atomic Habits
#  Author:James Clear
#  Status: Not Available

# %%
# Single Inheritance:
# Parent Class:

class Car:

    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

car1 = Car(4,5,"Petrol")
car1.drive()
# Out:
# The person will drive the Petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving: {self.is_selfdriving}")

tesla1 = Tesla(4,5,"Electricity",True)
tesla1.selfdriving()
# Out:
# Tesla supports self driving: True

# %%
tesla1.drive()
# Out:
# The person will drive the Electricity car

# %%
# Multi Inheritance:
# When class inherits more than one base class:

# Base Class1:
class Animal:
    
    def __init__(self,name):
        self.name = name

    def speak(self):
        print(f"Subclass must implement this method")

# Base class2:

class Pet:
    
    def __init__(self,owner):
        self.owner = owner

## Derived class:

class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} say woof woof"

# Creating object:

dog = Dog("Puppy","Yesh")
print(dog.speak())
print(dog.owner)
# Out:
# Puppy say woof woof
# Yesh

# %%
# Ex1: Vehicle Inheritance:

#Parent Class:
class Vehicle:
    def __init__(self,brand,color):
        self.brand = brand
        self.color = color
    def start(self):
        return f"The car brand is {self.brand} and color {self.color}"
    

# Child Class:
class Car(Vehicle):
    def __init__(self,brand,color,num_doors):
        super().__init__(brand,color)
        self.num_doors = num_doors

    def show_doors(self):
        return f"This {self.brand} car has {self.num_doors} doors"
    
class Bike(Vehicle):
    def __init__(self,brand,color,has_carrier):
        super().__init__(brand,color)
        self.has_carrier = has_carrier

    def check_carrier(self):
        if self.has_carrier:
            return "Has carrier"
        else:
            return "NO CARRIER"

car1= Car("Audi","Black",4)
print(car1.start())
print(car1.show_doors())
bike1 = Bike("RE","Blue",True)
print(bike1.check_carrier())
# Out:
# The car brand is Audi and color Black
# This Audi car has 4 doors
# Has carrier

# %%
class Device():
    def __init__(self,brand,battery_level):
        self.brand = brand
        self.battery_level = battery_level
    def show_info(self):
        return f"Device brand is: {self.brand}"
        return f"Battery_level is: {self.battery_level}"
    
class Camera():
    def take_photo(self):
        return f"Photo taken"
    
class Phone():
    def make_call(self,number):
        self.number = number
        return f"Calling {self.number}..."
    
# Child class:

class Smartphone(Device,Camera,Phone):
    def use_smartphone(self):
        return "Using smartphone features..."

my_phone = Smartphone("Samsung",85)

print(my_phone.show_info())
print(my_phone.take_photo())
print(my_phone.make_call("1232432434"))
print(my_phone.use_smartphone())
# Out:
# Device brand is: Samsung
# Photo taken
# Calling 1232432434...
# Using smartphone features...

# %%
class A:
    def __init__(self):
        self.source = "Class A"
    def msg(self):
        return "Message from A"

class B(A):
    def __init__(self):
        super().__init__()
        self.source = "Class B"
    def msg(self):
        return "Message from B"

class C(A):
    def __init__(self):
        super().__init__()
        self.source = "Class C"
    def msg(self):
        return "Message from C"
    
class D(B,C):
    def __init__(self):
        super().__init__()
    
    
d1 = D()
print(d1.msg())

print(f"Source:", d1.source)
print("MRO:",[cls.__name__ for cls in D.__mro__])
# Out:
# Message from B
# Source: Class B
# MRO: ['D', 'B', 'C', 'A', 'object']

# %%
class Account:
    def __init__(self,balance):
        self.balance = balance
    def check_balance(self):
        return f"Current balance in account is: {self.balance}"
    
class Taxpayer:
    def __init__(self,tax_id):
        self.tax_id = tax_id
    def file_tax(self):
        return f"Filed tax with the id: {self.tax_id}"
    
class User(Account,Taxpayer):
    def __init__(self,name,user_id,balance,tax_id):
        Account.__init__(self,balance)
        Taxpayer.__init__(self,tax_id)
        self.name = name
        self.user_id = user_id
    def show_details(self):
        return f"{self.name} is a user and user_id of {self.user_id} and tax_id of {self.tax_id} with a balance of {self.balance}"
    

user1 = User("Yeshu","A090","T23",3456)
print(user1.check_balance())
print(user1.file_tax())
print(user1.show_details())
# Out:
# Current balance in account is: T23
# Filed tax with the id: 3456
# Yeshu is a user and user_id of A090 and tax_id of 3456 with a balance of T23

# %%
# Polymorphism:

# Base Class:
class Animal:
    def speak(self):
        return "Sound of the animal"
    
# Derived class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"
    
# Derived class 2:
class Cat(Animal):
    def speak(self):
        return "Meow!"
    \
# polymorphism:
def animal_speak(animal):
    return animal.speak()

cat =Cat()
dog = Dog()

print(cat.speak())
print(dog.speak())
print(animal_speak(dog))
# Out:
# Meow!
# Woof!
# Woof!

# %%
class Shape:
    def area(self):
        return "The area of the figure"
    
class Rectangle(Shape):
    def __init__(self,height,width):
        self.height = height
        self.width = width
    def area(self):
        return self.height*self.width
    
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius * self.radius
    
def print_area(sample):
    return sample.area()    

rect1 = Rectangle(10,8)
print(rect1.area())
circle1 = Circle(3)
print(circle1.area())
print(print_area(circle1))
# Out:
# 80
# 28.259999999999998
# 28.259999999999998

# %%
from abc import ABC,abstractmethod

class Vehicle(ABC):
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"
    
class Bike(Vehicle):
    def start_engine(self):
        return "Bike engine started"
    
def start_vehicle(vehicle):
    return vehicle.start_engine()

car = Car()
bike = Bike()
start_vehicle(bike)
# Out:
# 'Bike engine started'

# %%
# Inheritance:
class Book:
    def __init__(self,title,author,price):
        self.title = title
        self.author = author
        self.price = price
    def get_info(self):
        return f"Title: {self.title}, Author : {self.author}, Price: ${self.price}"
    
class Ebook(Book):
    def __init__(self,title,author,price,file_size):
        super().__init__(title,author,price)
        self.file_size = file_size
    def get_info(self):
        base_info = super().get_info()
        return f"{base_info}, FileSize :{self.file_size}MB"
    
book1 = Ebook("ABC","Yesh",30,2)
book1.get_info()
# Out:
# 'Title: ABC, Author : Yesh, Price: $30, FileSize :2MB'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
class Student(Person):
    def __init__(self,name,age,roll_number):
        super().__init__(name,age)
        self.roll_number = roll_number

class Result(Student):
    def __init__(self,name,age,roll_number,marks):
        super().__init__(name,age,roll_number)
        self.marks = marks

    def display_result(self):
        avg_marks = sum(self.marks.values())/len(self.marks)
        return f"{self.name} is {self.age} old with roll number {self.roll_number} scored a average of {avg_marks}"

marks = {"Maths":56,"Science": 98, "English": 87}  
stu1 = Result("Yesh",12,"R18",marks)
stu1.display_result()
# Out:
# 'Yesh is 12 old with roll number R18 scored a average of 80.33333333333333'

# %%
class User:
    def __init__(self,name,email):
        self.name = name
        self.email = email
    def show_profile(self):
        return f"{self.name} is a user having mail-id of {self.email}"
    
class Course:
    def __init__(self,course_name,quiz_scores):
        self.course_name = course_name
        self.quiz_scores = quiz_scores
    def average_score(self):
        average = sum(self.quiz_scores)/len(self.quiz_scores)
        return average
    
class Student(User,Course):
    def __init__(self,name,email,course_name,quiz_scores,student_id):
        User.__init__(self,name,email)
        Course.__init__(self,course_name,quiz_scores)
        self.student_id = student_id
    def get_details(self):
         return (
            f"Name: {self.name}\n"
            f"Email: {self.email}\n"
            f"Student ID: {self.student_id}\n"
            f"Course: {self.course_name}\n"
            f"Scores: {self.quiz_scores}\n"
            f"Average Score: {self.average_score():.2f}\n"
            f"Passed: {'Yes' if self.has_passed() else 'No'}")
    def has_passed(self):
        return self.average_score() >=60
        
s1 = Student("Rev","revt.3@gmail.com","Python",[67,8,6],"R12")
print(s1.get_details())
print(s1.average_score())
print(s1.has_passed())
# Out:
# Name: Rev
# Email: revt.3@gmail.com
# Student ID: R12
# Course: Python
# Scores: [67, 8, 6]
# Average Score: 27.00
# Passed: No
# 27.0
# False

# %%
# POlymorphism

class Paymentmethod:
    def pay(self,amount):
        return "Subclasses must implement this method"
    
class CreditCard(Paymentmethod):
    def pay(self,amount):
        return f"Paid {amount} through Credit Card"
    
class PayPal(Paymentmethod):
    def pay(self,amount):
        return f"Paid {amount} through PayPal"
    
class UPI(Paymentmethod):
    def pay(self,amount):
        return f"Paid {amount} through UPI"
    
methods = [CreditCard(),PayPal(),UPI()]
for method in methods:
    print(method.pay(100))
# Out:
# Paid 100 through Credit Card
# Paid 100 through PayPal
# Paid 100 through UPI

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def get_bonus(self):
        return "Bonus"
    
class Manager(Employee):
    def get_bonus(self):
        bonus = self.salary * 0.20
        return bonus
    
    
class Developer(Employee):
    def get_bonus(self):
        bonus = self.salary * 0.10
        return bonus
    
employees = [Manager("John",100000), Developer("Rev",120000)]
for each in employees:
    print(each.get_bonus())
# Out:
# 20000.0
# 12000.0

# %%
from abc import ABC, abstractmethod

class FileReader(ABC):
    @abstractmethod
    def read(self):
        pass

class PDFReader(FileReader):
    def read(self):
        print("Reading a PDF File...")

class CSVReader(FileReader):
    def read(self):
        print("Reading a CSV File...")

class TextReader(FileReader):
    def read(self):
        print("Reading a Text File...")

readers = [PDFReader(), CSVReader(), TextReader()]
for r in readers:
    r.read()
# Out:
# Reading a PDF File...
# Reading a CSV File...
# Reading a Text File...

# %%
class Notifier:
    def send(self,message):
        pass

class EmailNotifier(Notifier):
    def send(self,message):
        return f"Sends email notifiactions: {message}"

class SMSNotifier:
    def send(self,message):
        return f"Sends SMS notifiactions: {message}"
    
class PushNotifier:
    def send(self,message):
        return f"Sends app push notifiactions: {message}"
    
messages = [EmailNotifier(), SMSNotifier(), PushNotifier()]
for each in messages:
    print(each.send("Hello!! Have a good one...."))
# Out:
# Sends email notifiactions: Hello!! Have a good one....
# Sends SMS notifiactions: Hello!! Have a good one....
# Sends app push notifiactions: Hello!! Have a good one....

# %%
class Paymentmethod:
    def process_payment(self,amount):
        pass

class CreditCard(Paymentmethod):
    def process_payment(self,amount):
        total_processed = amount + (amount * 0.02)
        return f"Credit card charged: ${total_processed}"
    
class PayPal(Paymentmethod):
    def process_payment(self,amount):
        total_processed = amount + (amount * 0.03)
        return f"PayPal charged: ${total_processed}"
    
class BitCoin(Paymentmethod):
    def process_payment(self,amount):
        if amount >= 50:
            return f"Bitcoin charged: ${amount}"
        else:
            return "Bitcoin Under $50 Cant get processed!!!"
        
methods = [CreditCard(), PayPal(), BitCoin()]
for method in methods:
    print(method.process_payment(30))
# Out:
# Credit card charged: $30.6
# PayPal charged: $30.9
# Bitcoin Under $50 Cant get processed!!!

# %%
class Shape:
    def area(self):
        return area
    def draw(self):
        return "Drawing Shape"

class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
    def draw(self):
        return f"Drawing rectangle of area:{self.area()}"
    
    
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius   
    def area(self):
        return 3.14 * self.radius * self.radius
    def draw(self):
        return f"Drawing circle of area: {self.area()} "
    
class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height = height
    def area(self):
        return 0.5 * self.base * self.height
    def draw(self):
        return f"Drawing triangle of area: {self.area()}"
    
shapes = [Rectangle(10,5), Circle(7), Triangle(6,4)]

for shape in shapes:
    #print(shape.area())
    print(shape.draw())
# Out:
# Drawing rectangle of area:50
# Drawing circle of area: 153.86
# Drawing triangle of area: 12.0

# %%
# Encapsulation without getter setter methods:

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

def get_name(person):
    return person.name
    
person = Person("Revt",37)
print(get_name(person))
# Out:
# Revt

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self,name,age,gender):
        self.__name = name
        self.__age = age
        self.__gender = gender

def get_name(person):
    return person.__name
person = Person("Revt",37,'F')
print(get_name(person))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8     return person.__name
#       9 person = Person("Revt",37,'F')
# ---> 10 print(get_name(person))
#
# Cell In[5], line 8, in get_name(person)
#       7 def get_name(person):
# ----> 8     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
dir(person)
# Out:
# ['_Person__age',
#  '_Person__gender',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    def __init__(self,name,age,gender):
        self._name = name
        self._age = age
        self.gender = gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)

emp = Employee("revt",37,'F')
print(emp._name)
# Out:
# revt

# %%
class Person:
    def __init__(self,name,age):
        self.__name = name
        self.__age = age
    
    def get_name(self):
        return self.__name
    def set_name(self,name):
        self.__name = name

    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age > 0:
            self.__age = age
        else:
            print("Age cannot be negative")

person = Person("REvt",34)
print(person.get_name())
print(person.get_age())


person.set_name('Yesh')
print(person.get_name())
person.set_age(-1)
# Out:
# REvt
# 34
# Yesh
# Age cannot be negative

# %%
# INheritance:

class Employee:
    def __init__(self,name,emp_id):
        self.name = name
        self.emp_id = emp_id

class FullTimeEmployee(Employee):
    def __init__(self,name,emp_id,base_salary):
        super().__init__(name,emp_id)
        self.base_salary = base_salary

    def calculate_pay(self):
        pay = self.base_salary + (self.base_salary * 0.10)
        return f"Total pay: ${pay}"
    
class PartTimeEmployee(Employee):
    def __init__(self,name,emp_id,hours,hourly_pay):
        super().__init__(name,emp_id)
        self.hours = hours
        self.hourly_pay = hourly_pay

    def calculate_pay(self):
        pay = self.hours * self.hourly_pay
        return f"Total pay: ${pay}"
    
e1 = FullTimeEmployee("John","E123",6700)
e2 = PartTimeEmployee("Milo","E129",20,40)
    
print(e1.calculate_pay())
print(e2.calculate_pay())
# Out:
# Total pay: $7370.0
# Total pay: $800

# %%
# Inheritance:

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def get_details(self):
        return f"Name: {self.name}, \nAge: {self.age}"

class Staff(Person):
    def __init__(self,name,age,staff_id):
        super().__init__(name,age)
        self.staff_id = staff_id
    
    def get_details(self):
        return super().get_details() + f"\nStaff_ID: {self.staff_id}"
    
class Professor(Staff):
    def __init__(self,name,age,staff_id,courses):
        super().__init__(name,age,staff_id)
        self.courses = courses
    
    def get_details(self):
        return (super().get_details() + "\nRole: Professor" + f"\nCourses: {self.courses}")

class Administrator(Staff):
    def __init__(self,name,age,staff_id,department):
         super().__init__(name,age,staff_id)
         self.department = department
    
    def get_details(self):
         return (super().get_details() +  "\nRole:Administrator" + f"\nDepartment: {self.department}")

class Guest:
    def __init__(self,guest_id):
        self.guest_id = guest_id

    def get_guest_info(self):
        return f" \nGuest_ID: {self.guest_id}"
    
class VisitingProfessor(Professor,Guest):
    def __init__(self,name,age,staff_id,guest_id,courses):
        Professor.__init__(self,name,age,staff_id,courses)
        Guest.__init__(self,guest_id)

    def get_details(self):
        return  (f"Name: {self.name} \nAge: {self.age} \nStaff_ID:{self.staff_id}" + f"{self.get_guest_info()}" +  f"\nRole: Visiting Professor \nCourses: {self.courses}")
        
    
emp1 = Professor("Dr.Smith",45,"P123",['AI',"ML"])
emp2 = Administrator("Alice",50,"A456",'HR')
emp3 = VisitingProfessor("Dr.Ray",60,"VP001","G789",["Data Science"])

print("\n",emp1.get_details())
print("\n",emp2.get_details())
print("\n",emp3.get_details())
# Out:
#  Name: Dr.Smith,
# Age: 45
# Staff_ID: P123
# Role: Professor
# Courses: ['AI', 'ML']
#
#  Name: Alice,
# Age: 50
# Staff_ID: A456
# Role:Administrator
# Department: HR
#
#  Name: Dr.Ray
# Age: 60
# Staff_ID:VP001
# Guest_ID: G789
# Role: Visiting Professor
# Courses: ['Data Science']

# %%
class Vehicle:
    def __init__(self,brand,model,rental_rate):
        self.brand = brand
        self.model = model
        self.rental_rate = rental_rate
    
    def calculate_rent(self,days):
        self.days = days
        return self.rental_rate * days
        
    
class Car(Vehicle):
    def __init__(self,brand,model,rental_rate,luxury_tax_rate):
        super().__init__(brand,model,rental_rate)
        self.luxury_tax_rate = luxury_tax_rate

    def calculate_rent(self,days):
         base_rent = super().calculate_rent(days)
         return base_rent + (base_rent * self.luxury_tax_rate)
    
class Truck(Vehicle):
    def __init__(self,brand,model,rental_rate,cargo_weight):
        super().__init__(brand,model,rental_rate)
        self.cargo_weight = cargo_weight

    def calculate_rent(self,days):
         base_rent = super().calculate_rent(days)
         surcharge = (self.cargo_weight / 100) * 5
         return base_rent + surcharge
    
class Bike(Vehicle):
    def __init__(self,brand,model,rental_rate):
        super().__init__(brand,model,rental_rate)
        
    def calculate_rent(self,days):
         return super().calculate_rent(days)
    

vehicles = [Car("Toyota","Camry",50,0.10), 
            Truck("Volvo", "FH16", 100, 2000), 
            Bike("Yamaha", "R15", 20)]

for vehicle in vehicles:
    print(f"Rent for {type(vehicle).__name__}: ${vehicle.calculate_rent(5)}")
# Out:
# Rent for Car: $275.0
# Rent for Truck: $600.0
# Rent for Bike: $100

# %%
# Polymorphism:

#from abc import ABC, abstractmethod

class MediaFile():
    def __init__(self,filename):
        self.filename = filename

    #@abstractmethod
    def play(self):
        pass

class MP3File(MediaFile):
    def play(self):
        return f"Playing MP3 File: {self.filename}"
    
class MP4File(MediaFile):
    def play(self):
        return f"Playing MP4 File: {self.filename}"
    
class WAVFile(MediaFile):
    def play(self):
        return f"Playing WAV File: {self.filename}"
    
playlist = [MP3File("song.mp3"), MP4File("video.mp4"),WAVFile("sound.wav")]
#playlist = [MP3File(),MP4File(),WAVFile()]

for media in playlist:
    print(media.play())
# Out:
# Playing MP3 File: song.mp3
# Playing MP4 File: video.mp4
# Playing WAV File: sound.wav

# %%
# polymorphism - Advanced:

from abc import ABC, abstractmethod

class Notification(ABC):
    @abstractmethod
    def send(self,message):
        pass

class EmailNotification(Notification):
    def send(self,message):
        return f"Sending Email: {message}"
    
class SMSNotification(Notification):
    def send(self,message):
        return f"Sending SMS: {message}"
    
class PushNotification(Notification):
    def send(self,message):
        return f"Sending Push alert: {message}"
    
def send_notification(message):
    notifications = [EmailNotification(), SMSNotification(), PushNotification()]
    result = []
    for notification in notifications:
        result.append(notification.send(message))
    return result
    
message_to_send = "Yor OTP is 1287"
for result in send_notification(message_to_send):
    print(result)
# Out:
# Sending Email: Yor OTP is 1287
# Sending SMS: Yor OTP is 1287
# Sending Push alert: Yor OTP is 1287

# %%
class Notification():
    def send(self,message):
        pass

class EmailNotification(Notification):
    def send(self,message):
        return f"Sending Email: {message}"
    
class SMSNotification(Notification):
    def send(self,message):
        return f"Sending SMS: {message}"
    
class PushNotification(Notification):
    def send(self,message):
        return f"Sending Push alert: {message}"
    

notifications = [EmailNotification(), SMSNotification(), PushNotification()]
    
    
for notification in notifications:
    print(notification.send("Your OTP is 1266"))
# Out:
# Sending Email: Your OTP is 1266
# Sending SMS: Your OTP is 1266
# Sending Push alert: Your OTP is 1266

# %%
# Encapsulation:

# Public:

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

def get_name(person):
    return person.name

person1 = Person("Yesh",12)
print(get_name(person1))
# Out:
# Yesh

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
#Private:

class Person:
    def __init__(self,name,age,gender):
        self.__name = name
        self.__age = age
        self.gender = gender

def get_name(person):
    return person.name

person = Person("Revt",23,"Female")
print(get_name(person))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 11
#       8     return person.name
#      10 person = Person("Revt",23,"Female")
# ---> 11 print(get_name(person))
#
# Cell In[131], line 8, in get_name(person)
#       7 def get_name(person):
# ----> 8     return person.name
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
# protected:

class Person:
    def __init__(self,name,age,gender):
        self._name = name
        self._age = age
        self.gender = gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)

employee = Employee("Yesh",12,"F")
employee._name
# Out:
# 'Yesh'

# %%
# Encapsulation with getter and setter:

class Person:
    def __init__(self,name,age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self,name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self,age):
        if age>0:
            self.__age = age
        else:
            print("Age cannot be negative")

person = Person("Yesh",13)
print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-8)
# Out:
# Yesh
# 13
# 35
# Age cannot be negative

# %%
class Student:
    def __init__(self,name):
        self.name = name
        self.__grades = []

    def add_grade(self,grade):
        if grade > 0 and grade <=100:
            self.__grades.append(grade)
        else:
            return "Invalid grade - Enter valid grade"
        
    def get_average(self):
        return sum(self.__grades)/len(self.__grades)

    def get_grades(self):
        return self.__grades.copy()

s1 = Student("Alice")
s1.add_grade(23)
s1.add_grade(98)
s1.add_grade(110)
print(s1.get_average())
print(s1.get_grades())
# Out:
# 60.5
# [23, 98]

# %%
# Encapsulation:

class BankAccount:
    def __init__(self,account_holder,balance):
        self.__account_holder = account_holder
        self.__balance = balance

    def deposit(self,amount):
        if amount > 0:
            self.__balance += amount
            return amount
        else:
            return "Invalid"
        
    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -= amount
            return amount
        else:
            return "Insufficient balance"
        
    def get_balance(self):
        return self.__balance
    
    def get_account_holder(self):
        return self.__account_holder
    
acc1 = BankAccount("Rev",3400)  
print(acc1.get_account_holder()) 
print(acc1.deposit(3000))
print(acc1.get_balance())
# Out:
# Rev
# 3000
# 6400

# %%
from abc import ABC,abstractmethod

## Abstract base cclass
class Vehicle(ABC):
    def drive(self):
        print("The vehicle is used for driving")

    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car enginer started")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car=Car()
operate_vehicle(car)
# Out:
# Car enginer started
# The vehicle is used for driving

# %%
class Person:
    def __init(self,name,age):
        self.name = name
        self.age = age

p1 =Person()
dir(Person)
# Out:
# ['_Person__init',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

person = Person("Yesh",12)
print(person)

# %%
## Basics Methods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def __str__(self):
        return f"{self.name},{self.age} years old"
    
    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"
    
person=Person("Revt",37)
print(person)
print(repr(person))
# Out:
# Revt,37 years old
# Person(name=Revt,age=37)

# %%
# Mathematical operation for vectors:

class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self,other):
        return Vector(self.x + other.x, self.y + other.y)
    
    def __sub__(self,other):
        return Vector(self.x - other.x, self.y - other.y)
    
    def __mul__(self,other):
        return Vector(self.x * other.x, self.y * other.y)
    
    def __eq__(self,other):
        return Vector(self.x == other.x and self.y == other.y)
    
    def __repr__(self):
        return f"Vector({self.x},{self.y})"
    
v1 = Vector(2,3)
v2 = Vector(4,5)

print(v1+v2)
print(v2-v1)
print(v1*v2)
# Out:
# Vector(6,8)
# Vector(2,2)
# Vector(8,15)

# %%
class ComplexNumber:
    def __init__(self,real,imag):
        self.real = real
        self.imag = imag

    def __add__(self,other):
        return ComplexNumber(self.real + other.real, self.imag + other.imag)
    
    def __sub__(self,other):
        return ComplexNumber(self.real - other.real, self.imag - other.imag)
    
    def __mul__(self,other):
        real_part = self.real * other.real - self.imag * other.imag
        img_part = self.real * other.imag + self.imag * other.real
        return ComplexNumber(real_part,img_part)
    
    def __truediv__(self,other): 
        denominator = other.real**2 + other.imag**2
        real_part = (self.real * other.real - self.imag * other.imag) / denominator
        img_part = (self.real * other.imag + self.imag * other.real) / denominator
        return ComplexNumber(real_part,img_part)

    def __eq__I(self,other):
        return self.real == other.real and self.imag == other.imag
    
    def __repr__(self):
        return f"{self.real} + {self.imag}i"

# Create objects of the ComplexNumber class
c1 = ComplexNumber(2, 3)
c2 = ComplexNumber(1, 4)

# Use overloaded operators
print(c1 + c2)  # Output: 3 + 7i
print(c1 - c2)  # Output: 1 - 1i
print(c1 * c2)  # Output: -10 + 11i
print(c1 / c2)  # Output: 0.8235294117647058 - 0.29411764705882354i
print(c1 == c2) # Output: False
# Out:
# 3 + 7i
# 1 + -1i
# -10 + 11i
# -0.5882352941176471 + 0.6470588235294118i
# False
