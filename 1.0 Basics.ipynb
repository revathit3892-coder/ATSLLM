# %% [markdown]
# Ex: x=5+2
#
# Syntax: The code is properly structured.
#
# Semantics: It means “add 5 and 2 and store 7 in x.”

# %%
# Case-sensitivity - Puython is case sensitive

name="Yesh"
Name="Rev"

print(name)
print(Name)

name==Name
# Out:
# Yesh
# Rev
# False

# %%
# Indentation:

age = 31
if age<30:
    print(age)
print(age)
# Out:
# 31

# %%
# Single-line comment

print("Hi!")
# Out:
# Hi!

# %%
# Line Continuation:

total = 1+2+3+3+\
4+3+5

print(total)
# Out:
# 21

# %%
# Multiple statement on a single line

x=5;y=10;z=x+y

print(z)
# Out:
# 15

# %%
# name error

a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # name error
# ----> 3 a=b
#
# NameError: name 'b' is not defined

# %%
# Code examples of Indentation:

if True:
    print("Indented properly")
    if False:
        print("Not printed")
    print("But it prints")
print("Outside the if block")
# Out:
# Indented properly
# But it prints
# Outside the if block

# %%
age=25
print(type(age))

# type conversion:
age_str=str(age)
print(type(age_str))
type(age_str)
# Out:
# <class 'int'>
# <class 'str'>
# str

# %%
age='25'
type(age)
type(int(age))
# Out:
# int

# %%
name='Yesh'
type(name)
type(int(name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 name='Yesh'
#       2 type(name)
# ----> 3 type(int(name))
#
# ValueError: invalid literal for int() with base 10: 'Yesh'

# %%
ht=5.7
type(ht)
# Out:
# float

# %%
float(int(ht))
# Out:
# 5.0

# %%
# Input

age=int(input("Enter your age:"))
print(age,type(age))
# Out:
# 23 <class 'int'>

# %%
# Simple Calculator:

a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))

addition=a+b
sub=a-b
mul=a*b
div=a/b

print("Sum:",addition)
print("Difference:",sub)
print("Multiply:",mul)
print("Divide:",div)
# Out:
# Sum: 15
# Difference: 5
# Multiply: 50
# Divide: 2.0

# %%
is_student=True
type(is_student)
# Out:
# bool

# %%
a=10
b=5

print(a==b)
type(a==b)
# Out:
# False
# bool

# %%
res="hello"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 res="hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
res="hello"+"5"
print(res)
# Out:
# hello5

# %%
res="hello"+str(5)
print(res)
# Out:
# hello5

# %%
str.isupper(res)
# Out:
# False

# %%
name1="Yesh"
name2="Yesh"
print(name1!=name2)
# Out:
# False

# %%
x=True
y=False

print(x and y)
print(x or y)
print(not y)
# Out:
# False
# True
# True
