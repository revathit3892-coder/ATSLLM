# %%
# read a whole file:

with open('test.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello World!
# Welcome all

# %%
# Read a file line by line:

with open("test.txt",'r') as file:
    for line in file:
        print(line.strip()) # removes new line
# Out:
# Hello World!
# Welcome all

# %%
with open('test.txt','w') as file:

    file.write("This is a new line")

with open('test.txt','r') as file:
    print(file.read())
# Out:
# This is a new line

# %%
with open('test.txt','a') as file:
    file.write("\n new line added")

with open("test.txt",'r') as file:
    print(file.read())
# Out:
# This is a new line
#  new line added

# %%
lines = ['\n First line \n','Second line \n','Third line \n']
with open('test.txt','a') as file:
    file.writelines(lines)

with open('test.txt','r') as file:
    print(file.read())
# Out:
# This is a new line
#  new line added
#  First line
# Second line
# Third line

# %%
# Writing binary files

data = b'\x00\x01\x02\x03'
with open ('example.bin','wb') as file:
    file.write(data)

# %%
with open('example.bin','rb') as file:
    print(file.read())
# Out:
# b'\x00\x01\x02\x03'

# %%
with open('test.txt','r') as source_file:
    content = source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
with open('destination.txt','r') as destination_file:
    print(destination_file.read())
# Out:
# This is a new line
#  new line added
#  First line
# Second line
# Third line

# %%
def count_text_file(file_path):
    with open(file_path, 'r')as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count =sum(len(line) for line in lines)
    return line_count,word_count,char_count

file_path = 'test.txt'
lines,words,characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 5, Words: 14, Characters: 73

# %%
with open('test.txt','w+') as file:
    file.write("Hello World!")
    file.write("\nWelcome all")
    
    file.seek(0)
    print(file.read())
# Out:
# Hello World!
# Welcome all

# %%
import os
cwd = os.getcwd()
print(f"Current working directory is: {cwd}")
# Out:
# Current working directory is: /Users/revathithangadurai/ATSLLM

# %%
new_directory="package1"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# Directory 'package1' create

# %%
## Listing Files And Directories

print(os.listdir('.'))
# Out:
# ['destination.txt', '3. Data Stuctures.ipynb', '5. Modules.ipynb', '4. Functions.ipynb', '2. Control Flow.ipynb', 'virtual_env', 'package1', '.ipynb', 'example.bin', 'test.txt', 'myenv', '5.Modules', '1.0 Basics.ipynb', 'package', '6. File Handling.ipynb']

# %%
### Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
### Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/revathithangadurai/ATSLLM/folder/file.txt

# %%
path = 'example1.txt'

if os.path.exists(path):
    print(f"The path {path} exists")
else:
    print(f"The path {path} doesnt exists")
# Out:
# The path example1.txt doesnt exists

# %%
import os
path = 'test.txt'
if os.path.isfile(path):
    print(f"The path '{path}' ia a file")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory")
else:
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'test.txt' ia a file

# %%
relative_path = 'test.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/revathithangadurai/ATSLLM/test.txt
